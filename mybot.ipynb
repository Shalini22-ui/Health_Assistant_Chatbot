# %%
import ollama

# %%
response = ollama.chat(
    model = 'phi3:mini',
    messages=[
        {
            'role' : 'user',
            'content' : 'what is deep learning?'
        }
    ]
)

print(response['message']['content'])
# Out:
# Deep Learning, a subset of machine learning that mimics the workings of the human brain—albeit far more basic by current technological standards—in processing data and creating patterns for use in recognizing images, sound, speech, written language, and other sensory inputs. It involves neural networks with multiple layers between input and output which help to identify various levels of abstractions. Neural networks are systems modeled loosely after the human brain that can "learn" from large amounts of data. They contain interconnected nodes (like neurons in a biological brain) called perceptrons, or artificial neurons. Deep learning uses complex models with many layers to learn and process inputs through these intricate connections – hence why it's referred to as 'deep'. It has shown remarkable results in various applications like image recognition, natural language processing (NLP), speech recognition etc., often surpassing human performance levels especially when dealing with large volumes of data.

# %%
response = ollama.chat(
    model = 'phi3:mini',
    messages = [
        {
            'role' : 'user',
            'content' : "hii"
        }
    ]
)
print(response['message']['content'])
# Out:
# Hello there! How can I help you today? Are you looking for information, assistance with a project, or perhaps just seeking some company in this vast digital sea of data we navigate daily? Let'thy me know how best to serve thee.
