# %%
import ollama

# %%
response = ollama.chat(
    model = 'phi3:mini',
    messages=[
        {
            'role' : 'user',
            'content' : 'what is deep learning?'
        }
    ]
)

print(response['message']['content'])
# Out:
# Deep Learning refers to a subset of machine learning involving layers of artificial neural networks that attempt to simulate the way the human brain operates. These systems learn from unstructured or structured data, recognizing patterns and making decisions with little human intervention. Deep learning is particularly effective for complex tasks like image recognition, natural language processing, and speech recognition where pattern identification in large datasets can be challenging without advanced algorithms that deep learning provides.
#
# Deep neural networks consist of multiple non-linear transformations applied over at least three layers - an input layer, several hidden layers (the depth), and an output layer. Each node within these layers is connected through weighted connections which are adjusted during the training phase via a process called backpropagation using gradient descent or similar optimization algorithms to minimize error between predicted and actual outputs on given tasks like classification or regression problems in supervised learning, or by defining suitable loss functions for unsupervised approaches.
#
# The term 'deep' signifies networks with many layers which enables the representation of complex concepts through hierarchical abstractions built from raw data inputs up to high-level features necessary for solving specific prediction tasks like classification and detection problems in computer vision applications, or natural language understanding where deep learning systems have shown exceptional performance surpassing traditional machine learning methods.

# %%
response = ollama.chat(
    model = 'phi3:mini',
    messages = [
        {
            'role' : 'user',
            'content' : "hii"
        }
    ]
)
print(response['message']['content'])
# Out:
# Hello there! How can I help you today? Are you looking for information, assistance with a project, or perhaps just seeking some company in this vast digital sea of data we navigate daily? Let'thy me know how best to serve thee.
